# %% [markdown]
# # Concept Bottleneck Models - Quick Start
#
# This notebook demonstrates how to use the Concept Bottleneck Models implementation.
#
# ## Disclaimer
#
# **IMPORTANT**: This notebook is for research and educational purposes only. XAI outputs may be unstable or misleading. This tool is NOT a substitute for human judgment and should NOT be used for regulated decisions without human review.
